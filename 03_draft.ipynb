# %%
# todo
# - read the email df
# - use the df and sample one
# - write test cases for each or pick that sample up and write for that case

# %%
import os
import re
from pathlib import Path
import email
from datetime import datetime
import imaplib
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
EMAIL = os.environ.get("EMAIL")
APP_PASSWORD = os.environ.get("APP_PASSWORD")

# %%
# dataset for testing filter logic
data_dir = Path("./data")
email_dataset = pd.read_csv(data_dir / "mail_samples_7th_Apr_24.csv")
email_dataset.head()
# Out:
#                                              subject  \
# 0         Check out New Jobs Posted by Top Companies
# 1             lunarflu mentioned you in Hugging Face
# 2                "Comparing with Apple.... too much"
# 3  Suprriya Kauul ( She / Her / Hers) sent you a ...
# 4  Rina (Owner)  has a Residential House in Kaikh...
#
#                                          from  \
# 0            "iimjobs.com" <info@iimjobs.com>
# 1         Discord <notifications@discord.com>
# 2             Reddit <noreply@redditmail.com>
# 3    LinkedIn <messages-noreply@linkedin.com>
# 4  Magicbricks <projectsonmb@magicbricks.com>
#
#                                                 body sent_files  \
# 0  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 1  \r\n    <!doctype html>\r\n    <html xmlns="ht...        NaN
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...        NaN
# 3  -----------------------------------------\r\n\...        NaN
# 4  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...        NaN
#
#                         date
# 0  2024-03-31 16:34:37+00:00
# 1  2024-03-31 15:50:21+00:00
# 2  2024-03-31 15:44:47+00:00
# 3  2024-03-31 13:21:48+00:00
# 4  2024-03-31 18:47:30+05:30

# %%
for idx, row in email_dataset.iterrows():
    matched = re.findall(r"\<(.*)@(.*)\.com\>", row["from"])
    if matched:
        email_dataset.at[idx, "email_type"] = matched[0][0]
        email_dataset.at[idx, "sender"] = matched[0][1]

# %%
def login_to_gmail(email: str, app_password: str) -> imaplib.IMAP4_SSL:
    try:
        connection = imaplib.IMAP4_SSL("imap.gmail.com")
        connection.login(email, app_password)
        print("Login successful")
        return connection
    except imaplib.IMAP4.error:
        print("Login failed")
        return None


def list_mailboxes(connection: imaplib.IMAP4_SSL) -> None:
    print("List of Mailboxes:")
    status, mailbox_list = connection.list()
    if status == "OK":
        for mailbox in mailbox_list:
            mbox_str = [
                re.sub(r"[\\\(\)]", "", e.strip())
                for e in mailbox.decode().split('"/"')
            ]
            print(f"{mbox_str[1]}: {mbox_str[0]}")


def get_body_text(msg):
    body_texts = []
    # process multi-part message
    if msg.is_multipart():
        for part in msg.walk():
            if "attachment" not in str(part.get("Content-Disposition")):
                body = part.get_payload(decode=True)
                if body:
                    try:
                        body_texts.append(body.decode())
                    except UnicodeDecodeError:
                        continue
    else:
        # process message with single part
        try:
            body_texts.append(msg.get_payload(decode=True).decode())
        except UnicodeDecodeError:
            pass
    return "\n".join(body_texts)


def mailbox_df(email_id_list, connection):
    all_emails = []
    for entry in tqdm(email_id_list):

        status, msg_data = connection.fetch(entry, "(RFC822)")
        if status == "OK":
            msg = email.message_from_bytes(msg_data[0][1])
            all_emails.append(
                {
                    "subject": msg.get("Subject"),
                    "from": msg.get("From"),
                    "body": get_body_text(msg),
                    "date": msg.get("Date"),
                }
            )
    return pd.DataFrame(all_emails)

# %%
def delete_emails(imap_connection, email_ids):
    """
    Marks the emails with the given IDs for deletion and expunges them.

    Args:
        imap_connection: The IMAP connection object.
        email_ids: A list of email IDs (strings) to delete.
    """
    if not email_ids:
        print("Email list to delete is empty.")
        return

    status, _ = imap_connection.store(" ".join(email_ids), "+FLAGS", "\\Deleted")
    if status != "OK":
        print(f"Error marking emails for deletion, emails: {email_ids}")

    status, _ = imap_connection.expunge()
    if status != "OK":
        print(f"Error expunging deleted emails")
    print("Email deletion process completed.")

# %%
connection = login_to_gmail(EMAIL, APP_PASSWORD)
mailbox = "INBOX"

status, _ = connection.select(mailbox)
if status == "OK":
    print(f"{mailbox} Selected")
else:
    print(f"Error Selecting {mailbox} ")

job_alert_on = False
if not job_alert_on:
    mark_job_alert_emails(connection)
# Out:
# OK
# OK

# %%
status, _ = connection.expunge()
if status != "OK":
    print(f"Error expunging deleted emails")
print("Email deletion process completed.")
# Out:
# Email deletion process completed.

# %%
connection.close()
connection.logout()

# %% [markdown]
# ### Data Analysis

# %%
# linkedin specific
# have a status called looking for job or not

# %%
linkedin_mails = email_dataset.loc[email_dataset["sender"] == "linkedin"]
linkedin_mails.head()
# Out:
#                                               subject  \
# 3   Suprriya Kauul ( She / Her / Hers) sent you a ...
# 5   =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 25  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 40  SAJID, you have new application updates this week
# 46  Add Goutam Bhat, Assistant Manager | Data Scie...
#
#                                                  from  \
# 3            LinkedIn <messages-noreply@linkedin.com>
# 5   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 25  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 40               LinkedIn <jobs-noreply@linkedin.com>
# 46           LinkedIn <messages-noreply@linkedin.com>
#
#                                                  body sent_files  \
# 3   -----------------------------------------\r\n\...        NaN
# 5   Your job alert for machine learning engineer i...        NaN
# 25  Your job alert for data scientist in Bengaluru...        NaN
# 40  Check out the status of your applications on L...        NaN
# 46  Do you know Goutam Bhat?\r\n22 mutual connecti...        NaN
#
#                          date         email_type    sender
# 3   2024-03-31 13:21:48+00:00   messages-noreply  linkedin
# 5   2024-03-31 11:53:07+00:00  jobalerts-noreply  linkedin
# 25  2024-03-31 11:53:07+00:00  jobalerts-noreply  linkedin
# 40  2024-04-02 21:18:08+00:00       jobs-noreply  linkedin
# 46  2024-04-02 14:17:39+00:00   messages-noreply  linkedin

# %%
email_dataset[email_dataset.sender == "iimjobs"]
# Out:
#                                                subject  \
# 0           Check out New Jobs Posted by Top Companies
# 7    Interesting Job Opportunity JP Morgan Chase - ...
# 15                       Some Handpicked Jobs for you!
# 20             iimjobs.com - Your Personalized Jobfeed
# 27   Top Jobs from Leading Companies based on your ...
# 38             iimjobs.com - Your Personalized Jobfeed
# 44   WorkIndia is hiring for Data Analyst - eCommer...
# 74   WorkIndia is hiring for Data Analyst - eCommer...
# 77   Tata Steel - Senior Technologist - Process Sim...
# 79                       Some Handpicked Jobs for you!
# 90             iimjobs.com - Your Personalized Jobfeed
# 91   HuQuo is hiring for Manager/Senior Manager - D...
# 101  Top Jobs from Leading Companies based on your ...
# 105  WorkIndia is hiring for Data Analyst - eCommer...
# 114  HighLevel - Product Manager - Support AI & Ope...
# 121                      Some Handpicked Jobs for you!
# 132                      Some Handpicked Jobs for you!
# 138            iimjobs.com - Your Personalized Jobfeed
# 149  Top Jobs from Leading Companies based on your ...
# 161  WorkIndia is hiring for Data Analyst - eCommer...
# 162  HuQuo is hiring for Manager/Senior Manager - D...
# 170                      Some Handpicked Jobs for you!
# 173            iimjobs.com - Your Personalized Jobfeed
# 185  Top Jobs from Leading Companies based on your ...
# 187  Interesting Job Opportunity JP Morgan Chase - ...
# 197  Tata Steel - Senior Technologist - Process Sim...
# 201                      Some Handpicked Jobs for you!
# 204         Check out New Jobs Posted by Top Companies
# 208  Interesting Job Opportunity JP Morgan Chase - ...
# 238  Interesting Job Opportunity Valiance Solutions...
# 244  10+ Matching Jobs from Leading Companies based...
# 251  Interesting Job Opportunity Valiance Solutions...
# 258            iimjobs.com - Your Personalized Jobfeed
# 260         Check out New Jobs Posted by Top Companies
# 273                      Some Handpicked Jobs for you!
# 276                      Some Handpicked Jobs for you!
# 279            iimjobs.com - Your Personalized Jobfeed
# 288  Interesting Job Opportunity Assistant Manager ...
# 294  10+ Matching Jobs  based on your preferences f...
#
#                                  from  \
# 0    "iimjobs.com" <info@iimjobs.com>
# 7    "iimjobs.com" <info@iimjobs.com>
# 15   "iimjobs.com" <info@iimjobs.com>
# 20   "iimjobs.com" <info@iimjobs.com>
# 27   "iimjobs.com" <info@iimjobs.com>
# 38   "iimjobs.com" <info@iimjobs.com>
# 44   "iimjobs.com" <info@iimjobs.com>
# 74   "iimjobs.com" <info@iimjobs.com>
# 77    Team iimjobs <info@iimjobs.com>
# 79   "iimjobs.com" <info@iimjobs.com>
# 90   "iimjobs.com" <info@iimjobs.com>
# 91   "iimjobs.com" <info@iimjobs.com>
# 101  "iimjobs.com" <info@iimjobs.com>
# 105  "iimjobs.com" <info@iimjobs.com>
# 114   Team iimjobs <info@iimjobs.com>
# 121  "iimjobs.com" <info@iimjobs.com>
# 132  "iimjobs.com" <info@iimjobs.com>
# 138  "iimjobs.com" <info@iimjobs.com>
# 149  "iimjobs.com" <info@iimjobs.com>
# 161  "iimjobs.com" <info@iimjobs.com>
# 162  "iimjobs.com" <info@iimjobs.com>
# 170  "iimjobs.com" <info@iimjobs.com>
# 173  "iimjobs.com" <info@iimjobs.com>
# 185  "iimjobs.com" <info@iimjobs.com>
# 187  "iimjobs.com" <info@iimjobs.com>
# 197   Team iimjobs <info@iimjobs.com>
# 201  "iimjobs.com" <info@iimjobs.com>
# 204  "iimjobs.com" <info@iimjobs.com>
# 208  "iimjobs.com" <info@iimjobs.com>
# 238  "iimjobs.com" <info@iimjobs.com>
# 244  "iimjobs.com" <info@iimjobs.com>
# 251  "iimjobs.com" <info@iimjobs.com>
# 258  "iimjobs.com" <info@iimjobs.com>
# 260  "iimjobs.com" <info@iimjobs.com>
# 273  "iimjobs.com" <info@iimjobs.com>
# 276  "iimjobs.com" <info@iimjobs.com>
# 279  "iimjobs.com" <info@iimjobs.com>
# 288  "iimjobs.com" <info@iimjobs.com>
# 294  "iimjobs.com" <info@iimjobs.com>
#
#                                                   body sent_files  \
# 0    Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 7    Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 15   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 20   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 27   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 38   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 44   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 74   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 77   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...        NaN
# 79   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 90   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 91   Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 101  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 105  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 114  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...        NaN
# 121  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 132  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 138  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 149  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 161  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 162  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 170  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 173  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 185  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 187  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 197  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...        NaN
# 201  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 204  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 208  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 238  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 244  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 251  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 258  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 260  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 273  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 276  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 279  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 288  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
# 294  Please Enable Javascript\n<!DOCTYPE html> <htm...        NaN
#
#                           date email_type   sender
# 0    2024-03-31 16:34:37+00:00       info  iimjobs
# 7    2024-03-31 09:35:53+00:00       info  iimjobs
# 15   2024-03-31 06:35:00+00:00       info  iimjobs
# 20   2024-03-31 03:14:59+00:00       info  iimjobs
# 27   2024-03-31 11:36:05+00:00       info  iimjobs
# 38   2024-04-03 02:52:01+00:00       info  iimjobs
# 44   2024-04-02 15:31:41+00:00       info  iimjobs
# 74   2024-04-02 09:33:29+00:00       info  iimjobs
# 77   2024-04-02 07:30:25+00:00       info  iimjobs
# 79   2024-04-02 06:30:58+00:00       info  iimjobs
# 90   2024-04-02 02:51:50+00:00       info  iimjobs
# 91   2024-04-01 15:31:41+00:00       info  iimjobs
# 101  2024-04-01 11:33:21+00:00       info  iimjobs
# 105  2024-04-01 09:33:31+00:00       info  iimjobs
# 114  2024-04-03 07:12:28+00:00       info  iimjobs
# 121  2024-04-03 06:34:42+00:00       info  iimjobs
# 132  2024-04-01 06:34:47+00:00       info  iimjobs
# 138  2024-04-01 02:53:54+00:00       info  iimjobs
# 149  2024-04-03 11:32:27+00:00       info  iimjobs
# 161  2024-04-03 09:33:37+00:00       info  iimjobs
# 162  2024-04-03 15:31:44+00:00       info  iimjobs
# 170  2024-04-04 06:35:46+00:00       info  iimjobs
# 173  2024-04-04 02:52:40+00:00       info  iimjobs
# 185  2024-04-05 11:31:17+00:00       info  iimjobs
# 187  2024-04-05 09:32:47+00:00       info  iimjobs
# 197  2024-04-05 07:12:50+00:00       info  iimjobs
# 201  2024-04-05 06:34:46+00:00       info  iimjobs
# 204  2024-04-05 16:29:45+00:00       info  iimjobs
# 208  2024-04-05 15:31:28+00:00       info  iimjobs
# 238  2024-04-06 15:34:16+00:00       info  iimjobs
# 244  2024-04-06 12:35:29+00:00       info  iimjobs
# 251  2024-04-06 09:35:54+00:00       info  iimjobs
# 258  2024-04-07 03:14:08+00:00       info  iimjobs
# 260  2024-04-06 16:34:02+00:00       info  iimjobs
# 273  2024-04-07 06:34:25+00:00       info  iimjobs
# 276  2024-04-06 06:32:09+00:00       info  iimjobs
# 279  2024-04-05 02:49:59+00:00       info  iimjobs
# 288  2024-04-04 15:31:56+00:00       info  iimjobs
# 294  2024-04-04 12:30:21+00:00       info  iimjobs

# %%
email_dataset.loc[email_dataset["sender_entity"] == "iimjobs"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Workspace/llm-notes/gmail-automate/gmail-automate/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sender_entity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 email_dataset.loc[email_dataset["sender_entity"] == "iimjobs"]
#
# File ~/Workspace/llm-notes/gmail-automate/gmail-automate/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/Workspace/llm-notes/gmail-automate/gmail-automate/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'sender_entity'

# %%
linkedin_mails.mail_type.value_counts()
# Out:
# mail_type
# jobalerts-noreply        28
# messages-noreply          5
# jobs-listings             3
# inmail-hit-reply          2
# jobs-noreply              1
# notifications-noreply     1
# Name: count, dtype: int64

# %%
linkedin_mails.loc[linkedin_mails["mail_type"] == "jobalerts-noreply"]
# Out:
#                                                subject  \
# 5    =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 25   =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 68   =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 71   =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 72   =?UTF-8?Q?=E2=80=9Cmachine_learning_enginee?=\...
# 78   =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 88   =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 99   =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D:_22...
# 100  =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 116  =?UTF-8?Q?Now_hiring:_4_=E2=80=9Cdata_scientis...
# 117  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 129  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 130  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 146  =?UTF-8?Q?Now_hiring:_12_=E2=80=9Cmachine_lear...
# 147  =?UTF-8?Q?Now_hiring:_30+_=E2=80=9Cdata_scient...
# 165  =?UTF-8?Q?Now_hiring:_1_=E2=80=9Cdata_scientis...
# 166  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 198  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 210  =?UTF-8?Q?Now_hiring:_1_=E2=80=9Cmachine_lea?=...
# 215  =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 216  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D:_28...
# 256  =?UTF-8?Q?Now_hiring:_3_=E2=80=9Cdata_scientis...
# 257  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 262  =?UTF-8?Q?Now_hiring:_14_=E2=80=9Cdata_scienti...
# 263  =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 291  =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
# 297  =?UTF-8?Q?=E2=80=9Cdata_scientist=E2=80=9D_opp...
# 303  =?UTF-8?Q?=E2=80=9Cmachine_learning_engineer=E...
#
#                                                   from  \
# 5    LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 25   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 68   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 71   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 72   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 78   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 88   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 99   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 100  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 116  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 117  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 129  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 130  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 146  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 147  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 165  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 166  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 198  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 210  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 215  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 216  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 256  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 257  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 262  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 263  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 291  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 297  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 303  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
#
#                                                   body sent_files  \
# 5    Your job alert for machine learning engineer i...        NaN
# 25   Your job alert for data scientist in Bengaluru...        NaN
# 68   Your job alert for machine learning engineer i...        NaN
# 71   Your job alert for data scientist in Bengaluru...        NaN
# 72   Your job alert for machine learning engineer i...        NaN
# 78   Your job alert for data scientist in Dublin\r\...        NaN
# 88   Your job alert for data scientist in Ireland\r...        NaN
# 99   Your job alert for data scientist in Bengaluru...        NaN
# 100  Your job alert for machine learning engineer i...        NaN
# 116  Your job alert for data scientist in Dublin\r\...        NaN
# 117  Your job alert for data scientist in Ireland\r...        NaN
# 129  Your job alert for data scientist in Ireland\r...        NaN
# 130  Your job alert for data scientist in Dublin\r\...        NaN
# 146  Your job alert for machine learning engineer i...        NaN
# 147  Your job alert for data scientist in Bengaluru...        NaN
# 165  Your job alert for data scientist in Dublin\r\...        NaN
# 166  Your job alert for data scientist in Ireland\r...        NaN
# 198  Your job alert for data scientist in Ireland\r...        NaN
# 210  Your job alert for machine learning engineer i...        NaN
# 215  Your job alert for machine learning engineer i...        NaN
# 216  Your job alert for data scientist in Bengaluru...        NaN
# 256  Your job alert for data scientist in Ireland\r...        NaN
# 257  Your job alert for data scientist in Dublin\r\...        NaN
# 262  Your job alert for data scientist in Bengaluru...        NaN
# 263  Your job alert for machine learning engineer i...        NaN
# 291  Your job alert for machine learning engineer i...        NaN
# 297  Your job alert for data scientist in Bengaluru...        NaN
# 303  Your job alert for machine learning engineer i...        NaN
#
#                           date          mail_type sender_entity
# 5    2024-03-31 11:53:07+00:00  jobalerts-noreply      linkedin
# 25   2024-03-31 11:53:07+00:00  jobalerts-noreply      linkedin
# 68   2024-04-02 14:48:22+00:00  jobalerts-noreply      linkedin
# 71   2024-04-02 11:49:28+00:00  jobalerts-noreply      linkedin
# 72   2024-04-02 11:49:28+00:00  jobalerts-noreply      linkedin
# 78   2024-04-02 06:41:09+00:00  jobalerts-noreply      linkedin
# 88   2024-04-02 06:41:09+00:00  jobalerts-noreply      linkedin
# 99   2024-04-01 11:57:10+00:00  jobalerts-noreply      linkedin
# 100  2024-04-01 11:57:11+00:00  jobalerts-noreply      linkedin
# 116  2024-04-03 06:58:35+00:00  jobalerts-noreply      linkedin
# 117  2024-04-03 06:58:35+00:00  jobalerts-noreply      linkedin
# 129  2024-04-01 06:50:50+00:00  jobalerts-noreply      linkedin
# 130  2024-04-01 06:50:50+00:00  jobalerts-noreply      linkedin
# 146  2024-04-03 11:42:06+00:00  jobalerts-noreply      linkedin
# 147  2024-04-03 11:42:05+00:00  jobalerts-noreply      linkedin
# 165  2024-04-04 06:40:35+00:00  jobalerts-noreply      linkedin
# 166  2024-04-04 06:40:35+00:00  jobalerts-noreply      linkedin
# 198  2024-04-05 06:50:48+00:00  jobalerts-noreply      linkedin
# 210  2024-04-05 14:53:02+00:00  jobalerts-noreply      linkedin
# 215  2024-04-05 11:45:51+00:00  jobalerts-noreply      linkedin
# 216  2024-04-05 11:45:51+00:00  jobalerts-noreply      linkedin
# 256  2024-04-06 06:59:49+00:00  jobalerts-noreply      linkedin
# 257  2024-04-06 06:59:49+00:00  jobalerts-noreply      linkedin
# 262  2024-04-06 11:56:11+00:00  jobalerts-noreply      linkedin
# 263  2024-04-06 11:56:11+00:00  jobalerts-noreply      linkedin
# 291  2024-04-04 14:37:53+00:00  jobalerts-noreply      linkedin
# 297  2024-04-04 11:54:07+00:00  jobalerts-noreply      linkedin
# 303  2024-04-04 11:54:08+00:00  jobalerts-noreply      linkedin

# %%
# Out:
# ('BYE', [b'LOGOUT Requested'])
